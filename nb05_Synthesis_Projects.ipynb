# %% [markdown]
# ## Project path
# (1) Estimate the volume of reservoir (where the fluid is flowing). For the Fervo project; Iceland and Japan assume 0.5 km cube. Estimate reservoir temperature conditions. <br>
# (2) Calculate physical properties and heat in place (done in nb04).  <br>
# (3) Calculate the fracture and porous flow models. <br>
# (4) Calculate the produced power and energy <br>
# (5) Complete the Barebones Thermoeconomic model. <br>
